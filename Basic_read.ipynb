# %%
# %sql
create volume if not exists lakehouse1.dbread.read_volume;

# %%
#dbutils.fs.rm("/Volumes/lakehouse1/dbread/read_volume/",recurse=True)

# %%
dbutils.fs.head("/Volumes/lakehouse1/dbread/read_volume/commondata/custs_header")

# %%
dbutils.fs.mkdirs("/Volumes/lakehouse1/dbread/read_volume/commondata")

# %%
df1=spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/custs_header",header=True,inferSchema=True).toDF("custid","first_name","last_name","Age","Profession")
display(df1)

# %%
df1=spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/custs_header_oth_del",sep="~", header=True,inferSchema=True)
display(df1)

# %%
df1_multiple_files=spark.read.csv(path=["/Volumes/lakehouse1/dbread/read_volume/commondata/dummy1/custs*","/Volumes/lakehouse1/dbread/read_volume/commondata/dummy2/custs*","/Volumes/lakehouse1/dbread/read_volume/commondata/mal*","/Volumes/lakehouse1/dbread/read_volume/commondata/custs*"],inferSchema=True).toDF("id","fname","lname","age","prof")
print(df1_multiple_files.count())

# %%
df1_multiple_files=spark.read.json(path="/Volumes/lakehouse1/dbread/read_volume/commondata/simple_json.txt")
df1_multiple_files.show()

# %%
#I am converting the CSV data into ORC data format to achieve SCHEMA EVOLUTION(CHANGING)
spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/source1.txt",inferSchema=True,header=True).write.orc("/Volumes/lakehouse1/dbread/read_volume/commondata/orc_targetdata_merged/",mode='overwrite')

spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/source2.txt",inferSchema=True,header=True).write.orc("/Volumes/lakehouse1/dbread/read_volume/commondata/orc_targetdata_merged/",mode='append')

spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/source3.txt",inferSchema=True,header=True).write.orc("/Volumes/lakehouse1/dbread/read_volume/commondata/orc_targetdata_merged/",mode='append')

# %%
orc_merged_data=spark.read.orc("/Volumes/lakehouse1/dbread/read_volume/commondata/orc_targetdata_merged/",mergeSchema=True)
display(orc_merged_data)
