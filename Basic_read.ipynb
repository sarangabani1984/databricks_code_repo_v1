# %%
# %sql
create volume if not exists lakehouse1.dbread.read_volume;

# %%
#dbutils.fs.rm("/Volumes/lakehouse1/dbread/read_volume/",recurse=True)

# %%
dbutils.fs.ls("/Volumes/lakehouse1/dbread/read_volume/")

# %%
dbutils.fs.mkdirs("/Volumes/lakehouse1/dbread/read_volume/commondata")

# %%
df1=spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/custs_header",header=True,inferSchema=True)
df1.printSchema()
display(df1)
