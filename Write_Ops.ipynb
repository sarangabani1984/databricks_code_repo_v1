# %%
spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/custsmodified").write.format("delta").save("/Volumes/lakehouse1/dbread/read_volume/commondata/custsmodified/delt")

# %%
print(dbutils.fs.ls("/Volumes/lakehouse1/dbread/read_volume/commondata/custsmodified/delt"))

# %%
df1=spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/custsmodified").toDF("id","fname","lname","age","prof")
df1.show()

# Display the schema (properties) of the DataFrame before writing to JSON
df1.write.json("/Volumes/lakehouse1/dbread/read_volume/commondata/json",mode="overwrite",compression="snappy")
print(dbutils.fs.ls("/Volumes/lakehouse1/dbread/read_volume/commondata/json"))

# %%
spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/malformeddata1.txt").show()

# %%
struct1="cid int,name int,amt double,dop date"
df1=spark.read.csv("/Volumes/lakehouse1/dbread/read_volume/commondata/malformeddata1.txt",header=False,sep=",",comment='#',quote="'",escape='~',schema= struct1,multiLine=True,ignoreLeadingWhiteSpace=True,ignoreTrailingWhiteSpace=True,dateFormat='yyyy-dd-MM')
df1.printSchema()
df1.show()

# %%
from pyspark.sql.functions import *
struct1="cid int,name int,amt double,dop date"
df1=spark.read.csv("/Volumes/workspace/default/volumewe47_datalake/malformeddata1.txt",header=False,sep=","
                                   ,comment='#',quote="'",escape='~',schema=struct1,multiLine=True,ignoreLeadingWhiteSpace=True,ignoreTrailingWhiteSpace=True,dateFormat='yyyy-dd-MM')#permit malformed records and allow me to do a RCA (Root cause analysis)
#df2=df1.withColumn("dop",to_date(date_format(col("dop"),"yyyy-dd-MM"),"yyyy-MM-dd"))
df1.printSchema()
df1.show()

# %%
df1.write.json("/Volumes/workspace/default/volumewe47_datalake/outputdata/jsonout",mode="overwrite", compression='gzip',dateFormat='yyyy-dd-MM',encoding='UTF-8',lineSep='~',ignoreNullFields=True)
